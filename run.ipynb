# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# 环境实例化
from envs.leo_env import LEOEnv
env = LEOEnv(json_path="data/parsed_data.json")

# %%
# 检查环境符合 Gym 接口规范
check_env(env, warn=True)

# %%
# 使用 MLP 策略
model = PPO("MlpPolicy", env, verbose=1, learning_rate=3e-4, batch_size=64, n_steps=2048)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# 训练
model.learn(total_timesteps=100000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2193 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012497704 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | -0.079      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.385       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 3.45        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008434619 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00875    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 0.00667     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010710958 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007451714 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00633     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010822827 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009329395 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 0.00095     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1192        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010192763 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000673   |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 0.000747    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012220646 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 0.000462    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1185        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011919629 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 0.000338    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011565113 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 0.000223    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012108101 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00577     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 0.000179    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1197         |
# |    iterations           | 13           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0094704535 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00571     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 0.000136     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1204        |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012147936 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.28       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0082      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 8.63e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016483795 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000942   |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 6.67e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 16          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011172201 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 4.38e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015009145 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.14       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0178      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 2.67e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1225       |
# |    iterations           | 18         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01033951 |
# |    clip_fraction        | 0.0764     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.11      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00421    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00299   |
# |    value_loss           | 2.19e-05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 19          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017371576 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 2.26e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 20          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008883485 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00102    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00274    |
# |    value_loss           | 1.43e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1221       |
# |    iterations           | 21         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00761266 |
# |    clip_fraction        | 0.0995     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.01      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0113    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00184   |
# |    value_loss           | 7.39e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 22          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012046726 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 6.99e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1221        |
# |    iterations           | 23          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013163334 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.06e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 24          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011809051 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0352     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 3.21e-06    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1226      |
# |    iterations           | 25        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0087974 |
# |    clip_fraction        | 0.0799    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.88     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00651   |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.00283  |
# |    value_loss           | 3.1e-06   |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 26           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0114624165 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0374       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00772     |
# |    value_loss           | 1.29e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 27          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010734855 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000886    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 1.4e-05     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1234       |
# |    iterations           | 28         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00997548 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.83      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00659    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00415   |
# |    value_loss           | 6.39e-06   |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1236     |
# |    iterations           | 29       |
# |    time_elapsed         | 48       |
# |    total_timesteps      | 59392    |
# | train/                  |          |
# |    approx_kl            | 0.014723 |
# |    clip_fraction        | 0.187    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.72    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0244  |
# |    n_updates            | 280      |
# |    policy_gradient_loss | -0.00737 |
# |    value_loss           | 1.14e-05 |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 30          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011842364 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0137      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 9.2e-05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 31          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011319974 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 7.65e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 32          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011541567 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0045      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 3.43e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1243        |
# |    iterations           | 33          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.021785684 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 3.13e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1245        |
# |    iterations           | 34          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015836885 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 9e-07       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 35          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012344524 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00417    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 1.45e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 36          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010472226 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0065     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 2.15e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 37          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010795487 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 1.73e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 38          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020996444 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 3.04e-08    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 39          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013979003 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 7.39e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 40          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014071883 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0085      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 2.23e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 41          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.016193587 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 2.78e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 42          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.016851641 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00932    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 1.16e-08    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 43          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017796118 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00756    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 9.56e-09    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 44          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011517761 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00359     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 1.73e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 45          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011614567 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0026     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 0.000244    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 46          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017692192 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00766    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0094     |
# |    value_loss           | 2.1e-11     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 47          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.012039258 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 2.17e-11    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 48          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010287171 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 1.83e-11    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1226        |
# |    iterations           | 49          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010244029 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 1.11e-11    |
# -----------------------------------------

# %%
# 保存模型
model.save("model/ppo_leoenv")

# %%
# 测试
obs, _ = env.reset()
for _ in range(10000):
    action, _ = model.predict(obs)
    obs, reward, done, _, info = env.step(action)
    env.render()
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 action, _ = model.predict(obs)
#       5 obs, reward, done, _, info = env.step(action)
# ----> 6 env.render()
#       7 if done:
#       8     break
#
# File ~/Documents/Project/Dissertation_Experiment/envs/leo_env.py:359, in LEOEnv.render(self)
#     357 node = self.nodes.get((task.plane_at, task.order_at))
#     358 if node is not None:
# --> 359     ax.scatter([node.x], [node.y], [node.z], color=task_colors[i], s=120, marker='o', label=f'Task {task.id}')
#     360     # 任务状态文本
#     361     ax.text(node.x, node.y, node.z+2, f'T{task.id} L{task.layer_id} {"Done" if task.is_done else ""}', color=task_colors[i], fontsize=9)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:2967, in Axes3D.scatter(self, xs, ys, zs, zdir, s, c, depthshade, axlim_clip, *args, **kwargs)
#    2964 if self._zmargin < 0.05 and xs.size > 0:
#    2965     self.set_zmargin(0.05)
# -> 2967 self.auto_scale_xyz(xs, ys, zs, had_data)
#    2969 return patches
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:609, in Axes3D.auto_scale_xyz(self, X, Y, Z, had_data)
#     607     self.zz_dataLim.update_from_data_x(Z, not had_data)
#     608 # Let autoscale_view figure out how to use this data.
# --> 609 self.autoscale_view()
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:656, in Axes3D.autoscale_view(self, tight, scalex, scaley, scalez)
#     654     if not _tight:
#     655         y0, y1 = ylocator.view_limits(y0, y1)
# --> 656     self.set_ybound(y0, y1, self._view_margin)
#     658 if scalez and self.get_autoscalez_on():
#     659     z0, z1 = self.zz_dataLim.intervalx
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:741, in Axes3D.set_ybound(self, lower, upper, view_margin)
#     719 def set_ybound(self, lower=None, upper=None, view_margin=None):
#     720     """
#     721     Set the lower and upper numerical bounds of the y-axis.
#     722
#    (...)    739     invert_yaxis, yaxis_inverted
#     740     """
# --> 741     self._set_bound3d(self.get_ybound, self.set_ylim, self.yaxis_inverted,
#     742                       lower, upper, view_margin)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:691, in Axes3D._set_bound3d(self, get_bound, set_lim, axis_inverted, lower, upper, view_margin)
#     688 if upper is None:
#     689     upper = old_upper
# --> 691 set_lim(sorted((lower, upper), reverse=bool(axis_inverted())),
#     692         auto=None, view_margin=view_margin)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:941, in Axes3D.set_ylim(self, bottom, top, emit, auto, view_margin, ymin, ymax)
#     872 def set_ylim(self, bottom=None, top=None, *, emit=True, auto=False,
#     873              view_margin=None, ymin=None, ymax=None):
#     874     """
#     875     Set the 3D y-axis view limits.
#     876
#    (...)    939     >>> set_ylim(5000, 0)
#     940     """
# --> 941     return self._set_lim3d(self.yaxis, bottom, top, emit=emit, auto=auto,
#     942                            view_margin=view_margin, axmin=ymin, axmax=ymax)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/mpl_toolkits/mplot3d/axes3d.py:798, in Axes3D._set_lim3d(self, axis, lower, upper, emit, auto, view_margin, axmin, axmax)
#     796 lower -= delta
#     797 upper += delta
# --> 798 return axis._set_lim(lower, upper, emit=emit, auto=auto)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/axis.py:1215, in Axis._set_lim(self, v0, v1, emit, auto)
#    1196 """
#    1197 Set view limits.
#    1198
#    (...)   1211     turns off, None leaves unchanged.
#    1212 """
#    1213 name = self._get_axis_name()
# -> 1215 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
#    1216 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1217 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/axis.py:1745, in Axis.update_units(self, data)
#    1739 """
#    1740 Introspect *data* for units converter and update the
#    1741 ``axis.get_converter`` instance if necessary. Return *True*
#    1742 if *data* is registered for unit conversion.
#    1743 """
#    1744 if not self._converter_is_explicit:
# -> 1745     converter = munits.registry.get_converter(data)
#    1746 else:
#    1747     converter = self._converter
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/units.py:190, in Registry.get_converter(self, x)
#     186 else:
#     187     # ... and avoid infinite recursion for pathological iterables for
#     188     # which indexing returns instances of the same iterable class.
#     189     if type(first) is not type(x):
# --> 190         return self.get_converter(first)
#     191 return None
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/units.py:183, in Registry.get_converter(self, x)
#     181         pass
#     182 try:  # If cache lookup fails, look up based on first element...
# --> 183     first = cbook._safe_first_finite(x)
#     184 except (TypeError, StopIteration):
#     185     pass
#
# File ~/Documents/Project/Dissertation_Experiment/venv/lib/python3.12/site-packages/matplotlib/cbook.py:1735, in _safe_first_finite(obj)
#    1732 if isinstance(obj, np.flatiter):
#    1733     # TODO do the finite filtering on this
#    1734     return obj[0]
# -> 1735 elif isinstance(obj, collections.abc.Iterator):
#    1736     raise RuntimeError("matplotlib does not support generators as input")
#    1737 else:
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:
